# %%
from sympy import  *
import numpy as np
import math
import cmath
from sympy.abc import s
from IPython.display import display, Math
from splane import pzmap, bodePlot
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
from scipy import signal
from sympy import symbols, solve

num=[0.1, 0, 0.9]

""" den=[1, 1.41, 1]
my_tf = TransferFunction(num, den)
w, mag, phase = signal.bode(my_tf)
print('este es el pasa bajos')
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase) 
pzmap(my_tf)
"""
den=np.polymul([1, 1, 1], [1, 1])
my_tf = TransferFunction(num, den)
print(den)

w, mag, phase = signal.bode(my_tf)
print('este es el pasa bajos')
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase) 
pzmap(my_tf)

num=[1, 0, 1]
""" den=[1, 4.2426, 9]
my_tf = TransferFunction(num, den)

w, mag, phase = signal.bode(my_tf)
print('este es el pasa altos')
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase) 
pzmap(my_tf)
 """
den=np.polymul([1, 3, 9], [1, 3])
my_tf = TransferFunction(num, den)
print(den)
w, mag, phase = signal.bode(my_tf)
print('este es el pasa altos')
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.figure()
plt.semilogx(w, phase) 
pzmap(my_tf)
# Out:
# [1 2 2 1]
# este es el pasa bajos
# [ 1  6 18 27]
# este es el pasa altos
# (6, <AxesSubplot:xlabel='$\\sigma$', ylabel='j$\\omega$'>)
